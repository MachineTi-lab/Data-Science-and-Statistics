# %% [markdown]
# ### Data Standardization

# %%
import numpy as np
import pandas as pd
V1 = np.array([1,3,6,5,7])
V2 = np.array([7,7,5,8,12])
V3 = np.array([6,12,5,6,14])
df = pd.DataFrame(
    {"V1" :V1,
     "V2" :V2,
     "V3" :V3,})
df = df.astype(float)
df
# Out:
#     V1    V2    V3
# 0  1.0   7.0   6.0
# 1  3.0   7.0  12.0
# 2  6.0   5.0   5.0
# 3  5.0   8.0   6.0
# 4  7.0  12.0  14.0

# %% [markdown]
# ### Standardization

# %%
from sklearn import preprocessing

# %%
preprocessing.scale(df)
# Out:
# array([[-1.57841037, -0.34554737, -0.70920814],
#        [-0.64993368, -0.34554737,  0.92742603],
#        [ 0.74278135, -1.2094158 , -0.98198051],
#        [ 0.27854301,  0.08638684, -0.70920814],
#        [ 1.2070197 ,  1.81412369,  1.47297076]])

# %%
df
# Out:
#     V1    V2    V3
# 0  1.0   7.0   6.0
# 1  3.0   7.0  12.0
# 2  6.0   5.0   5.0
# 3  5.0   8.0   6.0
# 4  7.0  12.0  14.0

# %% [markdown]
# ### Normalization

# %%
preprocessing.normalize(df)
# Out:
# array([[0.10783277, 0.75482941, 0.64699664],
#        [0.21107926, 0.49251828, 0.84431705],
#        [0.64699664, 0.53916387, 0.53916387],
#        [0.4472136 , 0.71554175, 0.53665631],
#        [0.35491409, 0.60842415, 0.70982818]])

# %% [markdown]
# ### Min-Max

# %%
scaler = preprocessing.MinMaxScaler(feature_range = (10,20)) # scaler is translater object

# %%
scaler.fit_transform(df)
# Out:
# array([[10.        , 12.85714286, 11.11111111],
#        [13.33333333, 12.85714286, 17.77777778],
#        [18.33333333, 10.        , 10.        ],
#        [16.66666667, 14.28571429, 11.11111111],
#        [20.        , 20.        , 20.        ]])

# %% [markdown]
# ### Binarize

# %%
binarizer = preprocessing.Binarizer(threshold = 5).fit(df)

# %%
binarizer.transform(df)
# Out:
# array([[0., 1., 1.],
#        [0., 1., 1.],
#        [1., 0., 0.],
#        [0., 1., 1.],
#        [1., 1., 1.]])

# %% [markdown]
# ### 0-1 Transform

# %%
import seaborn as sns
tips = sns.load_dataset("tips")
df = tips.copy()
df_l = df.copy()

# %%
df_l.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df_l["yeni_sex"] = df_l["sex"].cat.codes ### It starts converting the detected value from 1.

# %%
df_l.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  yeni_sex  daha_yeni-sex
# 0       16.99  1.01  Female     No  Sun  Dinner     2         1              0
# 1       10.34  1.66    Male     No  Sun  Dinner     3         0              1
# 2       21.01  3.50    Male     No  Sun  Dinner     3         0              1
# 3       23.68  3.31    Male     No  Sun  Dinner     2         0              1
# 4       24.59  3.61  Female     No  Sun  Dinner     4         1              0

# %%
lbe = preprocessing.LabelEncoder()

# %%
df_l["daha_yeni-sex"] = lbe.fit_transform(df_l["sex"])

# %% [markdown]
# ### 1 And Others

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df_l.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  yeni_sex  daha_yeni-sex
# 0       16.99  1.01  Female     No  Sun  Dinner     2         1              0
# 1       10.34  1.66    Male     No  Sun  Dinner     3         0              1
# 2       21.01  3.50    Male     No  Sun  Dinner     3         0              1
# 3       23.68  3.31    Male     No  Sun  Dinner     2         0              1
# 4       24.59  3.61  Female     No  Sun  Dinner     4         1              0

# %%
df_l["yeni_gün"] = np.where(df_l["day"].str.contains("Sun"),1,0)
df_l.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  yeni_sex  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2         1
# 1       10.34  1.66    Male     No  Sun  Dinner     3         0
# 2       21.01  3.50    Male     No  Sun  Dinner     3         0
# 3       23.68  3.31    Male     No  Sun  Dinner     2         0
# 4       24.59  3.61  Female     No  Sun  Dinner     4         1
#
#    daha_yeni-sex  yeni_gun  yeni_gün
# 0              0         1         1
# 1              1         1         1
# 2              1         1         1
# 3              1         1         1
# 4              0         1         1

# %% [markdown]
# ### Multi Class Transformation

# %%
lbe = preprocessing.LabelEncoder()

# %%
df_l["daha_yeni_gun"] = lbe.fit_transform(df_l["day"])

# %%
df_l.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  yeni_sex  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2         1
# 1       10.34  1.66    Male     No  Sun  Dinner     3         0
# 2       21.01  3.50    Male     No  Sun  Dinner     3         0
# 3       23.68  3.31    Male     No  Sun  Dinner     2         0
# 4       24.59  3.61  Female     No  Sun  Dinner     4         1
#
#    daha_yeni-sex  yeni_gun  yeni_gün  daha_yeni_gun
# 0              0         1         1              2
# 1              1         1         1              2
# 2              1         1         1              2
# 3              1         1         1              2
# 4              0         1         1              2

# %% [markdown]
# ### One_Hot Transform And Dummy Variable Trap

# %%
df_one_hot = df.copy()

# %%
pd.get_dummies(df_one_hot, columns = ["sex"], prefix = ["sex"]).head()  ### Prefix == "sex_Male" , "sex_female"
# Out:
#    total_bill   tip smoker  day    time  size  sex_Male  sex_Female
# 0       16.99  1.01     No  Sun  Dinner     2     False        True
# 1       10.34  1.66     No  Sun  Dinner     3      True       False
# 2       21.01  3.50     No  Sun  Dinner     3      True       False
# 3       23.68  3.31     No  Sun  Dinner     2      True       False
# 4       24.59  3.61     No  Sun  Dinner     4     False        True

# %%
pd.get_dummies(df_one_hot , columns = ["day"], prefix = ["day"]).head()
# Out:
#    total_bill   tip     sex smoker    time  size  day_Thur  day_Fri  day_Sat  \
# 0       16.99  1.01  Female     No  Dinner     2     False    False    False
# 1       10.34  1.66    Male     No  Dinner     3     False    False    False
# 2       21.01  3.50    Male     No  Dinner     3     False    False    False
# 3       23.68  3.31    Male     No  Dinner     2     False    False    False
# 4       24.59  3.61  Female     No  Dinner     4     False    False    False
#
#    day_Sun
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True

# %% [markdown]
# ### Converting a continuous variable into a categorical variable

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
dff= df.select_dtypes(include = ["float64" , "int64"])

# %%
ex = preprocessing.KBinsDiscretizer(n_bins = [3,2,2], encode = "ordinal" ,strategy = "quantile").fit(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[143], line 1
# ----> 1 ex = preprocessing.KBinsDiscretizer(n_bins =[3,2,2], encode = "ordinal" ,strategy = "quantile").fit(df)
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\preprocessing\_discretization.py:252, in KBinsDiscretizer.fit(self, X, y, sample_weight)
#     244     X = resample(
#     245         X,
#     246         replace=False,
#     247         n_samples=self.subsample,
#     248         random_state=self.random_state,
#     249     )
#     251 n_features = X.shape[1]
# --> 252 n_bins = self._validate_n_bins(n_features)
#     254 if sample_weight is not None:
#     255     sample_weight = _check_sample_weight(sample_weight, X, dtype=X.dtype)
#
# File ~\anaconda3\Lib\site-packages\sklearn\preprocessing\_discretization.py:338, in KBinsDiscretizer._validate_n_bins(self, n_features)
#     335 n_bins = check_array(orig_bins, dtype=int, copy=True, ensure_2d=False)
#     337 if n_bins.ndim > 1 or n_bins.shape[0] != n_features:
# --> 338     raise ValueError("n_bins must be a scalar or array of shape (n_features,).")
#     340 bad_nbins_value = (n_bins < 2) | (n_bins != orig_bins)
#     342 violating_indices = np.where(bad_nbins_value)[0]
#
# ValueError: n_bins must be a scalar or array of shape (n_features,).
